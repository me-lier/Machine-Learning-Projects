# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML Projects/Project-2-Diabetes-Prediction/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X=df.drop(columns='Outcome', axis=1)
Y=df['Outcome']

# %%
X.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# dtype: float64

# %%
X_train.std()
# Out:
# Pregnancies                   3.376108
# Glucose                      31.756953
# BloodPressure                19.562986
# SkinThickness                16.082060
# Insulin                     118.564627
# BMI                           8.002726
# DiabetesPedigreeFunction      0.335720
# Age                          11.749655
# dtype: float64

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
X_train.std()
# Out:
# Pregnancies                   3.376108
# Glucose                      31.756953
# BloodPressure                19.562986
# SkinThickness                16.082060
# Insulin                     118.564627
# BMI                           8.002726
# DiabetesPedigreeFunction      0.335720
# Age                          11.749655
# dtype: float64

# %%
Y.std()
# Out:
# 0.47695137724279896

# %%
Y_train.std()
# Out:
# 0.47689466003809805

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaler=scaler.transform(X_train)

# %%
X_train_scaler
# Out:
# array([[-1.13796489, -0.07971099, -3.5556072 , ...,  0.02825037,
#         -0.98159708, -0.7885233 ],
#        [ 0.64067858, -0.52091877,  0.02549599, ..., -0.17184452,
#         -1.03823795,  0.31879426],
#        [-0.84152431,  2.12632792, -0.48609018, ..., -0.25938604,
#         -0.21545477,  2.19271628],
#        ...,
#        [ 2.12288146, -1.15121561,  0.23013046, ..., -0.25938604,
#         -0.50760242,  0.14843771],
#        [ 0.04779742, -0.30031488,  0.43476492, ...,  0.90366551,
#         -0.69839272,  0.40397253],
#        [-1.13796489, -1.11970076, -0.07682125, ...,  0.45345201,
#         -0.69243053, -0.70334503]])

# %%
scaler.fit(X_test)
# Out:
# StandardScaler()

# %%
X_test_scaler=scaler.transform(X_test)

# %%
model=svm.SVC(kernel='linear')

# %%
model.fit(X_train_scaler, Y_train)
# Out:
# SVC(kernel='linear')

# %%
#accuracy

# %%
X_train_prediction=model.predict(X_train_scaler)
acc=accuracy_score(X_train_prediction, Y_train)

# %%
acc
# Out:
# 0.7866449511400652

# %%
X_test_prediction=model.predict(X_test_scaler)
acc=accuracy_score(X_test_prediction, Y_test)

# %%
acc
# Out:
# 0.7532467532467533

# %%
input_data=(5,166,72,19,175,25.8,0.587,51)
arr=np.asarray(input_data)
arr_reshaped=arr.reshape(1,-1)
std_data=scaler.transform(arr_reshaped)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
std_data
# Out:
# array([[ 0.33794627,  1.45700413,  0.24284136, -0.04681131,  1.08742675,
#         -0.74416577,  0.3472192 ,  1.51030842]])

# %%
test=model.predict(std_data)

# %%
print(test)
# Out:
# [1]

# %%
if test==0:
  print("Non Diabetic")
else:
  print("Diabetic")
# Out:
# Diabetic
